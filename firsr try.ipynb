# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4, 0 ,-1, -2, -3, -4], [1,4,9,16,0, 1 , 4, 9, 16])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random

sns.histplot(random.normal(loc=50, scale=5, size=1000))
sns.histplot(random.binomial(n=100, p=0.5, size=1000))

plt.show()

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
